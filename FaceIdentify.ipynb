# %% [markdown]
# <a href="https://colab.research.google.com/github/quangphuc2509/AI-Homework/blob/main/FaceIdentify.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Khai báo và sử dụng các thư viện sau
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten,  LeakyReLU
from tensorflow.keras.optimizers import SGD, RMSprop
from keras.callbacks import EarlyStopping, ModelCheckpoint
from sklearn.utils import validation 
from sklearn import preprocessing
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
# %cd /content/drive/MyDrive/Kiemtragiuaky/FaceClass
# Out:
# /content/drive/MyDrive/Kiemtragiuaky/FaceClass

# %%
# Tạo ra class ImageDataGenerator để chỉnh sửa ảnh 
train=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
# Tạo bộ dữ liệu training set
training_set=train.flow_from_directory('/content/drive/MyDrive/Kiemtragiuaky/FaceClass/train',
                                               target_size=(30,40), batch_size=32, class_mode='categorical')
# Out:
# Found 1440 images belonging to 24 classes.

# %%
# Các nhãn có trong bộ dữ liệu training set
training_set.class_indices
# Out:
# {'Anh Kiet': 0,
#  'Bao Thai': 1,
#  'Bui Dang Khoa': 2,
#  'Hau': 3,
#  'Hoai Phong': 4,
#  'Hoang Thanh': 5,
#  'Hong Phuc': 6,
#  'Huu Long': 7,
#  'Minh Tien': 8,
#  'Ngoc Hieu': 9,
#  'Ngoc Minh': 10,
#  'Ngoc Sang': 11,
#  'Ngoc Thach': 12,
#  'Nguyen Bui Anh Kiet': 13,
#  'Nguyen Hoang': 14,
#  'Nguyen Tuan Kiet': 15,
#  'Pham Quang Huy': 16,
#  'Phuc Dung': 17,
#  'Quang Huy': 18,
#  'Quang Phuc': 19,
#  'Son Tung': 20,
#  'Tan Dat': 21,
#  'Tan Phat': 22,
#  'Viet Ha': 23}

# %%
# Tạo ra mạng CNN để train mô hình
model=Sequential()

model.add(Conv2D(32,(3,3), activation='linear', kernel_initializer='he_uniform', padding='same',input_shape=(30,40,3))) 
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))


model.add(Conv2D(64,(3,3), activation='linear', kernel_initializer='he_uniform', padding='same')) 
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))

model.add(Conv2D(128,(3,3), activation='linear', kernel_initializer='he_uniform', padding='same')) 
model.add(LeakyReLU(alpha = 0.1))
model.add(MaxPooling2D((2,2), padding = 'same'))

model.add(Flatten())
model.add(Dense(256,activation='linear',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(LeakyReLU(alpha = 0.1))
model.add(Dense(24,activation='softmax'))

# Biên dịch 
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 30, 40, 32)        896
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 30, 40, 32)        0
#
#  max_pooling2d_3 (MaxPooling  (None, 15, 20, 32)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 15, 20, 64)        18496
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 15, 20, 64)        0
#
#  max_pooling2d_4 (MaxPooling  (None, 8, 10, 64)        0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 8, 10, 128)        73856
#
#  leaky_re_lu_6 (LeakyReLU)   (None, 8, 10, 128)        0
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 5, 128)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 2560)              0
#
#  dense_2 (Dense)             (None, 256)               655616
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  leaky_re_lu_7 (LeakyReLU)   (None, 256)               0
#
#  dense_3 (Dense)             (None, 24)                6168
#
# =================================================================
# Total params: 755,032
# Trainable params: 755,032
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Gán biến lại để vẽ đồ thị, với 50 lần học (epochs), mỗi lần học thì chỉ học␣128 dữ liệu (batch_size), 
# khi sai số không thay đổi trong 30 lần học thì sẽ␣ dừng 
history=model.fit(training_set,epochs=50,batch_size=128,verbose=1)
# Out:
# Epoch 1/50
# 45/45 [==============================] - 845s 19s/step - loss: 2.4432 - accuracy: 0.3472
# Epoch 2/50
# 45/45 [==============================] - 3s 71ms/step - loss: 0.5400 - accuracy: 0.8292
# Epoch 3/50
# 45/45 [==============================] - 4s 79ms/step - loss: 0.2216 - accuracy: 0.9479
# Epoch 4/50
# 45/45 [==============================] - 3s 72ms/step - loss: 0.1588 - accuracy: 0.9556
# Epoch 5/50
# 45/45 [==============================] - 3s 69ms/step - loss: 0.1134 - accuracy: 0.9722
# Epoch 6/50
# 45/45 [==============================] - 3s 68ms/step - loss: 0.1116 - accuracy: 0.9688
# Epoch 7/50
# 45/45 [==============================] - 4s 79ms/step - loss: 0.0772 - accuracy: 0.9806
# Epoch 8/50
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0580 - accuracy: 0.9868
# Epoch 9/50
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0532 - accuracy: 0.9868
# Epoch 10/50
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0323 - accuracy: 0.9910
# Epoch 11/50
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0623 - accuracy: 0.9833
# Epoch 12/50
# 45/45 [==============================] - 3s 67ms/step - loss: 0.0609 - accuracy: 0.9812
# Epoch 13/50
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0562 - accuracy: 0.9854
# Epoch 14/50
# 45/45 [==============================] - 4s 78ms/step - loss: 0.0449 - accuracy: 0.9889
# Epoch 15/50
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0250 - accuracy: 0.9937
# Epoch 16/50
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0146 - accuracy: 0.9951
# Epoch 17/50
# 45/45 [==============================] - 3s 72ms/step - loss: 0.0169 - accuracy: 0.9979
# Epoch 18/50
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0226 - accuracy: 0.9944
# Epoch 19/50
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0163 - accuracy: 0.9958
# Epoch 20/50
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0138 - accuracy: 0.9979
# Epoch 21/50
# 45/45 [==============================] - 4s 81ms/step - loss: 0.0126 - accuracy: 0.9979
# Epoch 22/50
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0169 - accuracy: 0.9951
# Epoch 23/50
# 45/45 [==============================] - 3s 68ms/step - loss: 0.1296 - accuracy: 0.9674
# Epoch 24/50
# 45/45 [==============================] - 3s 71ms/step - loss: 0.0445 - accuracy: 0.9847
# Epoch 25/50
# 45/45 [==============================] - 4s 81ms/step - loss: 0.0230 - accuracy: 0.9958
# Epoch 26/50
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0265 - accuracy: 0.9931
# Epoch 27/50
# 45/45 [==============================] - 3s 71ms/step - loss: 0.0197 - accuracy: 0.9958
# Epoch 28/50
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0116 - accuracy: 0.9972
# Epoch 29/50
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0204 - accuracy: 0.9937
# Epoch 30/50
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0087 - accuracy: 0.9993
# Epoch 31/50
# 45/45 [==============================] - 3s 78ms/step - loss: 0.0079 - accuracy: 0.9986
# Epoch 32/50
# 45/45 [==============================] - 4s 91ms/step - loss: 0.0082 - accuracy: 0.9979
# Epoch 33/50
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0284 - accuracy: 0.9931
# Epoch 34/50
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0100 - accuracy: 0.9965
# Epoch 35/50
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0165 - accuracy: 0.9972
# Epoch 36/50
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0074 - accuracy: 0.9993
# Epoch 37/50
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0056 - accuracy: 0.9986
# Epoch 38/50
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0074 - accuracy: 0.9993
# Epoch 39/50
# 45/45 [==============================] - 3s 76ms/step - loss: 0.0073 - accuracy: 0.9993
# Epoch 40/50
# 45/45 [==============================] - 3s 68ms/step - loss: 0.0119 - accuracy: 0.9972
# Epoch 41/50
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0062 - accuracy: 0.9993
# Epoch 42/50
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0075 - accuracy: 0.9979
# Epoch 43/50
# 45/45 [==============================] - 4s 80ms/step - loss: 0.0076 - accuracy: 0.9993
# Epoch 44/50
# 45/45 [==============================] - 3s 70ms/step - loss: 0.0062 - accuracy: 0.9993
# Epoch 45/50
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0050 - accuracy: 0.9993
# Epoch 46/50
# 45/45 [==============================] - 3s 73ms/step - loss: 0.0040 - accuracy: 0.9993
# Epoch 47/50
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0045 - accuracy: 0.9993
# Epoch 48/50
# 45/45 [==============================] - 3s 68ms/step - loss: 0.0067 - accuracy: 0.9986
# Epoch 49/50
# 45/45 [==============================] - 3s 69ms/step - loss: 0.0057 - accuracy: 0.9993
# Epoch 50/50
# 45/45 [==============================] - 4s 82ms/step - loss: 0.0166 - accuracy: 0.9951

# %%
model.save('/content/drive/MyDrive/Kiemtragiuaky/FaceClass/FaceIdentify.h5')

# %%
# Đánh giá độ chính xác của mô hình 
Score=model.evaluate(training_set,verbose=0)
print('Train Loss', Score[0])
print('Train Accuracy', Score[1])
# Out:
# Train Loss 0.004584638401865959
# Train Accuracy 0.9979166388511658

# %%
# Vẽ đồ thị giữa số lần học (Epochs) và độ chính xác (Accuracy)
plt.plot(history.history['accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train'])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
model1= load_model('/content/drive/MyDrive/Kiemtragiuaky/FaceClass/FaceIdentify.h5')

# %%
test="/content/drive/MyDrive/Kiemtragiuaky/FaceClass/test"

for i in os.listdir(test):
  img=load_img(test+'/'+i,target_size=(30,40))
  plt.imshow(img)
  img=img_to_array(img)
  img=img.astype('float32')
  img=img/255
  img=np.expand_dims(img,axis=0)
  result=(model1.predict(img).argmax())
  class_name=['Anh Kiet','Bao Thai','Bui Dang Khoa','Hau','Hoai Phong', 'Hoang Thanh', 'Hong Phuc', 'Huu Long', 'Minh Tien',
              'Ngoc Hieu', 'Ngoc Minh', 'Ngoc Sang', 'Ngoc Thach','Nguyen Bui Anh Kiet', 'Nguyen Hoang', 'Nguyen Tuan Kiet', 'Pham Quang Huy',
              'Phuc Dung', 'Quang Huy', 'Quang Phuc', 'Son Tung', 'Tan Dat', 'Tan Phat', 'Viet Ha']
  print(class_name[result])
  plt.show()
# Out:
# 1/1 [==============================] - 0s 221ms/step
# Quang Phuc
# 1/1 [==============================] - 0s 18ms/step
# Ngoc Hieu
# 1/1 [==============================] - 0s 18ms/step
# Viet Ha
# 1/1 [==============================] - 0s 20ms/step
# Phuc Dung
# 1/1 [==============================] - 0s 19ms/step
# Nguyen Hoang
# 1/1 [==============================] - 0s 26ms/step
# Huu Long
# 1/1 [==============================] - 0s 18ms/step
# Anh Kiet
